# %%
### Code written by Rajat

'''Graphical Visualisation to compare efficiency of algorithms using Seaborn'''

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('algoCompare.csv')
df.head()
# Out:
#   Algorithm  TimeTaken  Nodes  Time/Node
# 0     astar     0.0098   1976   0.000005
# 1  dijkstra     0.0078   1523   0.000005
# 2     astar     0.0025    357   0.000007
# 3  dijkstra     0.0206   4876   0.000004
# 4  dijkstra     0.0117   2355   0.000005

# %%
df = df[df['Time/Node'] < 0.00025]
df.head()
# Out:
#   Algorithm  TimeTaken  Nodes  Time/Node
# 0     astar     0.0098   1976   0.000005
# 1  dijkstra     0.0078   1523   0.000005
# 2     astar     0.0025    357   0.000007
# 3  dijkstra     0.0206   4876   0.000004
# 4  dijkstra     0.0117   2355   0.000005

# %%
sns.scatterplot(y=df.TimeTaken,x=df.Nodes, hue = df.Algorithm)
plt.show()

# %%
sns.lineplot(x=df.Nodes, y= df["TimeTaken"], hue = df.Algorithm )
plt.show()

# %%
sns.violinplot(x=df.Algorithm, y=df.TimeTaken)
plt.show()
